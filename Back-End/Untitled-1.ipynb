# %%
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os
from urllib.parse import quote_plus
load_dotenv()
USER = os.getenv("user")
PASSWORD = os.getenv("password")
HOST = os.getenv("host")
PORT = os.getenv("port")
DBNAME = os.getenv("dbname")
engine = create_engine(f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}")
engine.connect()

# %%
import requests
from sqlalchemy import select, create_engine
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Requirement already satisfied: idna<4,>=2.5 in d:\web development\capstone projects\my portfolio\back-end\.venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\web development\capstone projects\my portfolio\back-end\.venv\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\web development\capstone projects\my portfolio\back-end\.venv\lib\site-packages (from requests) (2025.10.5)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
# Installing collected packages: charset_normalizer, requests
#
#    ---------------------------------------- 0/2 [charset_normalizer]
#    ---------------------------------------- 0/2 [charset_normalizer]
#    ---------------------------------------- 0/2 [charset_normalizer]
#    -------------------- ------------------- 1/2 [requests]
#    -------------------- ------------------- 1/2 [requests]
#    -------------------- ------------------- 1/2 [requests]
#    ---------------------------------------- 2/2 [requests]
#
# Successfully installed charset_normalizer requests
# Note: you may need to restart the kernel to use updated packages.
